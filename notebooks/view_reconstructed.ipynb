# %% [markdown]
# # To run this notebook
#
# + Ensure that you have [installed Nix](https://github.com/jacg/IC/tree/manage-with-nix/doc/nix/install-nix)
#
# + Paste this into your shell:
#   ```sh
#   git clone https://github.com/jacg/petalo.git
#   cd petalo
#   direnv allow
#   jupyter notebook notebooks/view_reconstructed.ipynb
#   ```
#
# Make sure that `file_in` (in the next cell) points to the location of the coincidences file on your system.

# %%
# Set this to point wherever your data are stored
file_in = "data/in/full_body_phantom_reco_combined.h5"

# Change this to `True` if you want to use true rather than reco data
use_true = False

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from utils import compare_c_rust
# Out:
# <style>.container { width:100% !important; }</style>

# %%
compare_c_rust(file_in=file_in, use_true=use_true)
# Out:
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -f data/in/full_body_phantom_reco_combined.h5
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -c -f data/in/full_body_phantom_reco_combined.h5

# %%
compare_c_rust(file_in=file_in, use_true=use_true,       tof=350)
# Out:
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 350 -f data/in/full_body_phantom_reco_combined.h5
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 350 -c -f data/in/full_body_phantom_reco_combined.h5

# %%
compare_c_rust(file_in=file_in, use_true=use_true,       tof=200)
# Out:
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 200 -f data/in/full_body_phantom_reco_combined.h5
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 200 -c -f data/in/full_body_phantom_reco_combined.h5

# %%
compare_c_rust(file_in=file_in, use_true=use_true,       tof=20)
# Out:
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 20 -f data/in/full_body_phantom_reco_combined.h5

# %%
compare_c_rust(file_in=file_in, use_true=use_true,       shape=(40,40,40))
# Out:
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -n 40,40,40 -f data/in/full_body_phantom_reco_combined.h5
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -n 40,40,40 -c -f data/in/full_body_phantom_reco_combined.h5
