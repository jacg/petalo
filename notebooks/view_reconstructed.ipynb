# %% [markdown]
# # To run this notebook
#
# + Ensure that you have [installed Nix](https://github.com/jacg/IC/tree/manage-with-nix/doc/nix/install-nix)
#
# + Paste this into your shell:
#   ```sh
#   git clone https://github.com/jacg/petalo.git
#   cd petalo
#   direnv allow
#   jupyter notebook notebooks/view_reconstructed.ipynb
#   ```
#
# Make sure that `file_in` (in the next cell) points to the location of the coincidences file on your system.

# %%
args = dict(
    # Set this to point wherever your data are stored
    #file_in = "data/in/test_lor_phantom.h5",
    file_in = 'cold-phantom-combined.h5',
    #file_in = "data/in/full_body_phantom_reco_combined.h5",

    # Number of events to read from input file [default: all events in file]
    #n_events = 350000,

    # Change this to `True` if you want to use true rather than reco data
    use_true = False,

    # Path to dataset within the HDF5 file, if different from default
    dataset = 'reco_info/lors',
    
    # Set to some truthy value if the dataset contains LORs rather than events
    read_lors = True,
    
    # Size of reconstruction region in mm [default: 360, 360, 360]
    size = (400,)*3,
    
)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from utils import compare_c_rust
# Out:
# <style>.container { width:100% !important; }</style>

# %%
compare_c_rust(**args)
# Out:
# Args(tof=None, shape=(60, 60, 60), iterations=6, c=False, use_true=False, file_in='cold-phantom-combined.h5', n_events=False, dataset='reco_info/lors', read_lors=True, size=(400, 400, 400))
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -s 400,400,400 -f cold-phantom-combined.h5 -d reco_info/lors --read-lors
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -s 400,400,400 -c -f cold-phantom-combined.h5 -d reco_info/lors --read-lors

# %%
compare_c_rust(**args,       tof=350)
# Out:
# Args(tof=350, shape=(60, 60, 60), iterations=6, c=False, use_true=False, file_in='cold-phantom-combined.h5', n_events=False, dataset='reco_info/lors', read_lors=True, size=(400, 400, 400))
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 350 -s 400,400,400 -f cold-phantom-combined.h5 -d reco_info/lors --read-lors
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 350 -s 400,400,400 -c -f cold-phantom-combined.h5 -d reco_info/lors --read-lors

# %%
compare_c_rust(**args,       tof=200)
# Out:
# Args(tof=200, shape=(60, 60, 60), iterations=6, c=False, use_true=False, file_in='cold-phantom-combined.h5', n_events=False, dataset='reco_info/lors', read_lors=True, size=(400, 400, 400))
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 200 -s 400,400,400 -f cold-phantom-combined.h5 -d reco_info/lors --read-lors
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 200 -s 400,400,400 -c -f cold-phantom-combined.h5 -d reco_info/lors --read-lors

# %%
compare_c_rust(**args,       tof=20)
# Out:
# Args(tof=20, shape=(60, 60, 60), iterations=6, c=False, use_true=False, file_in='cold-phantom-combined.h5', n_events=False, dataset='reco_info/lors', read_lors=True, size=(400, 400, 400))
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 20 -s 400,400,400 -f cold-phantom-combined.h5 -d reco_info/lors --read-lors
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -r 20 -s 400,400,400 -c -f cold-phantom-combined.h5 -d reco_info/lors --read-lors

# %%
compare_c_rust(**args,       shape=(40,40,40))
# Out:
# Args(tof=None, shape=(40, 40, 40), iterations=6, c=False, use_true=False, file_in='cold-phantom-combined.h5', n_events=False, dataset='reco_info/lors', read_lors=True, size=(400, 400, 400))
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -n 40,40,40 -s 400,400,400 -f cold-phantom-combined.h5 -d reco_info/lors --read-lors
#
# The required image files are missing. Generating them with:
#
#    cargo run --bin mlem --release --  -i 6 -n 40,40,40 -s 400,400,400 -c -f cold-phantom-combined.h5 -d reco_info/lors --read-lors
